# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 610.8/610.8 kB 8.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov5m.pt")
model.train(data="/content/drive/MyDrive/Colab Notebooks/label/model/data.yaml",epochs=80,model="yolov5m-seg.pt")
# Out:
# PRO TIP 💡 Replace 'model=yolov5m.pt' with new 'model=yolov5mu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics YOLOv8.0.163 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
