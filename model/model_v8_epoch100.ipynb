# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 610.8/610.8 kB 6.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8m.pt")
model.train(data="/content/drive/MyDrive/Colab Notebooks/label/model/data.yaml",epochs=100,model="yolov8m-seg.pt")
# Out:
# Ultralytics YOLOv8.0.163 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from PIL import Image
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('/content/runs/detect/train/weights/best.pt')

# Run inference on an image
results = model(['/content/test/t1.jpg', '/content/test/t2.jpg', '/content/test/t3.jpg'])  # list of 2 Results objects

# Show the results
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    im.show()  # show image
    im.save('results.jpg')  # save image    i++
# Out:
# 0: 640x640 1 walk_light_green, 1: 640x640 1 walk_light_red, 2: 640x640 2 walk_light_reds, 96.1ms
# Speed: 2.1ms preprocess, 32.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
