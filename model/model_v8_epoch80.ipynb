# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.5/609.5 kB 9.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8m.pt")
model.train(data="/content/drive/MyDrive/Colab Notebooks/label/model/data.yaml",epochs=80,model="yolov8m-seg.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:04<00:00, 12.8MB/s]
# Ultralytics YOLOv8.0.162 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
